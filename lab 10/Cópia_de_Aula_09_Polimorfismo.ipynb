# %% [markdown]
# <a href="https://colab.research.google.com/github/tavinh17/Atividades-poo-Ot-vio-Henrique/blob/main/C%C3%B3pia_de_Aula_09_Polimorfismo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pilares da OO: Polimorfismo
#
# * Poli: muitas
# * Morphos: formas
#
# O polimorfismo permite tratar objetos de diferentes tipos como o mesmo tipo geral. Assumindo que esses diferentes tipos obedecem um mesmo padrão de comportamento, podemos escrever códigos mais gerais, capazes de trabalhar com quaisquer desses tipos.
#
# <img src="https://drive.google.com/uc?id=1mKztPpEvd0KE-mFYruZ1J1j-BKzvhBDU" width=600>
#
#
# Já vimos a expressão do polimorfismo no Python com a **sobrecarga de operadores**, onde redefinimos o comportamento de operadores aritméticos (+, -, *, /) e relacionais (>, <, ==, etc.), além do comportamento de funções como o print (usando o método mágico `__str__()`) e operadores de lista.
#
# Podemos entender o polimorfismo com a sobrecarga de operadores da seguinte forma: ao ver uma expressão `a + b`, eu preciso saber qual o tipo de dados de `a` e de `b` para determinar o comportamento. A expressão escrita é a mesma, mas o comportamento vai variar. **Veja o exemplo a seguir com diferentes aplicações da soma**.

# %%
# soma de dois inteiros é operação aritmética
a, b = 10, 20
#################
print(a+b) # soma
#################

# soma de duas strings é concatenação
a, b = 'A', 'B'
#################
print(a+b) # soma
#################

# soma de dois pontos pode ser definida como
# operação geométrica
class Ponto:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __add__(self, outro_ponto):
        return(self.x + outro_ponto.x,
               self.y + outro_ponto.y)

a = Ponto(3,4)
b = Ponto(5,6)
#################
print(a+b) # soma
#################
# Out:
# 30
# AB
# (8, 10)

# %% [markdown]
# ### Sobrescarga de métodos com Herança
#
# No contexto da herança, o polimorfismo aparece quando reescrevemos um método da superclasse nas subclasses. Vejamos o exemplo a seguir onde modelamos mensagens enviadas e recebidas em um aplicativo que dá suporte a mensagens de Texto, Voz e Imagem.
#
# *   Superclasse `Mensagem` representa o tipo mais comum, mensagens de texto, com o método `exibir` sendo apenas um print e um método `exibirTamanho` que imprime quantos bytes tem a mensagem.
# *   `MensagemVoz` é uma subclasse que precisa de um tratamento especial para `exibir`, dar play no áudio.
# *   `MensagemImagem` é outra subclasse que também trata de forma diferente o comportamento de `exibir` mensagem.

# %%
import sys

class Mensagem:
    def __init__(self, conteudo):
        self.conteudo = conteudo

    def exibirTamanho(self):
        print(f'({sys.getsizeof(self.conteudo)} bytes)')

    def exibir(self):
        print(self.conteudo, end='')

class MensagemVoz(Mensagem):
    def __init__(self, conteudo):
        super().__init__(conteudo)

    def exibir(self):
        print(f'Dando play no arquivo de som {self.conteudo}', end='')

class MensagemImagem(Mensagem):
    def __init__(self, conteudo):
        super().__init__(conteudo)

    def exibir(self):
        print(f'Exibindo imagem {self.conteudo}', end='')

# %% [markdown]
# Agora pense numa classe `Conversa` que pode incluir todos os tipos de mensagens. A vantagem do polimorfismo é que a classe `Conversa` não precisa saber qual tipo específico de mensagem está armazenando. Ela simplesmente chama o método `exibir()`, e o tipo da variável vai determinar qual método será chamado! **Isso é polimorfismo!**
#
# Se amanhã você precisar adicionar um novo tipo de mensagem, como `MensagemVideo`, basta criar a nova subclasse sobrescrevendo o método `exibir()` e a classe `Conversa` continuará funcionando sem sofrer nenhuma alteração.
#
# Note que o método `exibirTamanho`, que também pode ser chamado pra qualquer classe na relação de herança, **não caracteriza polimorfismo** porque só existe um método implementado (o da superclasse) e é sempre ele a ser chamado.

# %%
class Conversa:
    def __init__(self):
        self.mensagens = []

    def adicionar_mensagem(self, mensagem):
        self.mensagens.append(mensagem)

    def exibir_todas(self):
        for i, mensagem in enumerate(self.mensagens, 1):
            print(f'{i}. ', end='')
            mensagem.exibir() ### polimorfismo!
            print(' ', end='')
            mensagem.exibirTamanho() ### não é polimorfismo!

conversa = Conversa()
conversa.adicionar_mensagem(Mensagem("Olá, tudo bem?"))
conversa.adicionar_mensagem(MensagemVoz("audio.mp3"))
conversa.adicionar_mensagem(MensagemImagem("foto.jpg"))
conversa.exibir_todas()
# Out:
# 1. Olá, tudo bem? (71 bytes)
# 2. Dando play no arquivo de som audio.mp3 (50 bytes)
# 3. Exibindo imagem foto.jpg (49 bytes)

# %% [markdown]
# E agora vamos conhecer o estilo de programação específico do Python, que torna o conceito de polimorfismo mais intuitivo.
#
# ### Duck Typing 🦆
# Você conhece o "[Teste do pato](https://pt.wikipedia.org/wiki/Teste_do_pato)"?
#
# > Se parece com um pato, nada como um pato e grasna como um pato, então provavelmente é um pato.
#
# O teste diz que podemos reconhecer uma entidade desconhecida através de **comportamentos** familiares. Na orientação a objetos, a palavra "comportamento" mapeia diretamente para métodos de uma classe. No [glossário do Python](https://docs.python.org/3/glossary.html#term-duck-typing), duck typing é definido como (texto adaptado):
#
# > *um estilo de programação que não verifica o tipo de um objeto; em vez disso, o método ou atributo é simplesmente chamado ou usado. (...) o código bem projetado melhora sua flexibilidade ao permitir a substituição polimórfica.*
#
# A particularidade do duck typing é que **ele não precisa envolver herança, basta que dois objetos implementem o mesmo comportamento**. Já conhecemos isso através dos protocolos de uso dos métodos mágicos. Por exemplo, qualquer classe que implemente os métodos mágicos `__getitem__()` e `__setitem__()` podem ser utilizados como lista sem precisar herdar nenhum tipo.
#
# Como Python não é uma linguagem fortemente tipada, contanto que um determinado tipo possua os atributos e métodos necessários para realizar um dado comportamento, seu tipo não importa. Vejamos o exemplo traduzido deste [tutorial do Real Python sobre duck typing](https://realpython.com/duck-typing-python/#duck-typing-behaving-like-a-duck).
#
# [![image alt text](http://img.youtube.com/vi/Nn7PQwXP0kU/0.jpg)](http://www.youtube.com/watch?v=Nn7PQwXP0kU)

# %%
class Pato:
    def nadar(self):
        print("O pato está nadando")

    def grasnar(self):
        print("O pato diz: AAAAAAAA")

class Marreco:
    def nadar(self):
        print("O marreco está nadando")

    def grasnar(self):
        print("O marreco diz: AAAAAAAA")

class Ganso:
    def nadar(self):
        print("O ganso está nadando")

    def grasnar(self):
        print("O ganso diz: AAAAAAAA")

# %%
patos = [Pato(), Marreco(), Ganso()]

for pato in patos:
    pato.nadar()
    pato.grasnar()
    print('-------')
# Out:
# O pato está nadando
# O pato diz: AAAAAAAA
# -------
# O marreco está nadando
# O marreco diz: AAAAAAAA
# -------
# O ganso está nadando
# O ganso diz: AAAAAAAA
# -------

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Q1.
# Considere o seguinte código Python que envolve polimorfismo, e responda as questões na célula seguinte.
# ```python
# class Animal:
#     def __init__(self, nome):
#         self.nome = nome
#     def exibirNome(self):
#         print(self.nome)
#     def fazerSom(self):
#         print(f"{self.nome} faz: AAA" )
#
# class Cachorro(Animal):
#     def __init__(self, nome):
#         super().__init__(nome)
#     def fazerSom(self):
#         print(f"Doguinho {self.nome} faz: AU AU" )
#
# class Gato(Animal):
#     def __init__(self, nome):
#         super().__init__(nome)
#     def fazerSom(self):
#         print(f"Gatinho {self.nome} faz: MIAAAU" )
#
# #Programa principal
# animais = [Animal("Bob"), Cachorro("Du"), Gato("Lele")]
# for animal in animais:
#     animal.exibirNome()
#     animal.fazerSom()
# ```

# %% [markdown]
# Altere essa célula para responder:
#
#
# *   Liste as superclasses: Animal
# *   Liste as subclasses: Cachorro e Gato
# *   Para cada subclasse, liste os **métodos herdados**: Cachorro: exibirNome()
#        Gato: exibirNome()
#
# *   Para cada subclasse, liste os **métodos definidos internamente**: Cachorro:   __init__() e fazerSom()
# Gato: __init__() e fazerSom()
#
# *   Quais linhas de código expressam o pilar do Polimorfismo? Justifique:      animal.fazerSom()
#
# *   Qual será a saída impressa quando o programa for executado?
#
# Bob
# Bob faz: AAA
# Du
# Doguinho Du faz: AU AU
# Lele
# Gatinho Lele faz: MIAAAU

# %% [markdown]
# ## Q2.
#
# Considere o seguinte código Python que envolve polimorfismo, e responda as questões na célula seguinte.
#
# ```python
# class Veiculo:
#     def mover(self, carga):
#         if isinstance(carga, str):
#             print(f"Veículo leva {carga}")
#         elif isinstance(carga, float):
#             print(f"Veículo com {carga} kilos")
#         elif isinstance(carga, int) and carga == 1:
#             print(f"Veículo com 1 carga")
#         else:
#             print("Veículo não tem capacidade para esse transporte")
#
# class Caminhao(Veiculo):
#     def mover(self, carga):
#         if isinstance(carga, str):
#             print(f"Caminhão leva {carga}")
#         elif isinstance(carga, float):
#             print(f"Caminhão com {carga} kilos")
#         elif isinstance(carga, int):
#             print(f"Caminhão com {carga} cargas")
#
#
# # Programa principal
# veiculos = [Veiculo(), Caminhao(), Veiculo(), Caminhao()]
# cargas_str = ['alimento', 'areia', 'carga viva', 'mobília']
# cargas_float = [10.5, 25.5, 5.2, 32.8]
# cargas_int = [1, 3, 5, 10]
#
# for i, v in enumerate(veiculos):
#     v.mover(cargas_str[i])
#     v.mover(cargas_float[i])
#     v.mover(cargas_int[i])
#     print("---")
# ```

# %% [markdown]
# Altere essa célula para responder:
#
# *   Quais linhas de código expressam o pilar do Polimorfismo? Justifique: v.mover(cargas_str[i])
# v.mover(cargas_float[i])
# v.mover(cargas_int[i])
#
# *   Qual será a saída impressa quando o programa for executado?
# Veículo leva alimento
# Veículo com 10.5 kilos
# Veículo com 1 carga
#
# Caminhão leva areia
# Caminhão com 25.5 kilos
# Caminhão com 3 cargas
#
# Veículo leva carga viva
# Veículo com 5.2 kilos
# Veículo não tem capacidade para esse transporte
#
# Caminhão leva mobília
# Caminhão com 32.8 kilos
# Caminhão com 10 cargas

# %% [markdown]
# ## Q3.
#
# Crie um sistema de cálculo de áreas de formas geométricas. O sistema deve ser desenvolvido com ênfase no pilar do Polimorfismo.
#
# Requisitos do Sistema:
#
# Superclasse - `FormaGeometrica`:
#
# * Atributo: area (inicializado com valor 0)
# * Método: calcularArea() - retorna a string "Superclasse não calcula área"
# * Método: imprimirArea() - imprime o valor do atributo area
#
#
# Subclasses:
#
# `Circulo`
# * Atributo: raio (recebido na inicialização)
# * Método: calcularArea() - calcula a área com a fórmula `3.14 * raio**2`, atualiza o atributo área e retorna "Área do círculo calculada com sucesso"
#
# `Retangulo`
# * Atributos: base e altura (recebidos na inicialização)
# * Método: calcularArea() - calcula a área com a fórmula `base * altura`, atualiza o atributo área e retorna "Área do retângulo calculada com sucesso"
#
# `Triângulo`
# * Atributo: base e altura (recebidos na inicialização)
# * Método: calcularArea() - calcula a área com a fórmula `(base * altura) / 2`, atualiza o atributo área e retorna "Área do triângulo calculada com sucesso"
#
#
# O programa principal deve ter uma lista de formas geométricas e apresentar um menu com as seguintes opções:
# * Criar nova forma: Perguntar qual tipo de forma deseja criar, criar a forma solicitada e armazenar na lista de formas
# * Calcular áreas: Percorrer a lista de formas e chamar o método `calcularArea()` para cada elemento
# * Exibir áreas: Percorrer a lista de formas e chamar o método `exibirArea()` para cada elemento.
# * Sair: Encerra o programa

# %%
class FormaGeometrica:
    def __init__(self):
        self.area = 0

    def calcularArea(self):
        return "Superclasse não calcula área"

    def imprimirArea(self):
        print(f"Área: {self.area}")


class Circulo(FormaGeometrica):
    def __init__(self, raio):
        super().__init__()
        self.raio = raio

    def calcularArea(self):
        self.area = 3.14 * self.raio ** 2
        return "Área do círculo calculada com sucesso"


class Retangulo(FormaGeometrica):
    def __init__(self, base, altura):
        super().__init__()
        self.base = base
        self.altura = altura

    def calcularArea(self):
        self.area = self.base * self.altura
        return "Área do retângulo calculada com sucesso"


class Triangulo(FormaGeometrica):
    def __init__(self, base, altura):
        super().__init__()
        self.base = base
        self.altura = altura

    def calcularArea(self):
        self.area = (self.base * self.altura) / 2
        return "Área do triângulo calculada com sucesso"


# Programa principal
formas = []

while True:
    print("\n===== MENU =====")
    print("1 - Criar nova forma")
    print("2 - Calcular áreas")
    print("3 - Exibir áreas")
    print("4 - Sair")

    opcao = input("Escolha uma opção: ")

    if opcao == "1":
        print("\n1 - Círculo")
        print("2 - Retângulo")
        print("3 - Triângulo")

        tipo = input("Escolha o tipo de forma: ")

        if tipo == "1":
            raio = float(input("Digite o raio: "))
            formas.append(Circulo(raio))
            print("Círculo criado com sucesso!")

        elif tipo == "2":
            base = float(input("Digite a base: "))
            altura = float(input("Digite a altura: "))
            formas.append(Retangulo(base, altura))
            print("Retângulo criado com sucesso!")

        elif tipo == "3":
            base = float(input("Digite a base: "))
            altura = float(input("Digite a altura: "))
            formas.append(Triangulo(base, altura))
            print("Triângulo criado com sucesso!")

        else:
            print("Tipo de forma inválido!")

    elif opcao == "2":
        for forma in formas:
            print(forma.calcularArea())

    elif opcao == "3":
        for forma in formas:
            forma.imprimirArea()

    elif opcao == "4":
        print("Programa encerrado!")
        break

    else:
        print("Opção inválida!")
# Out:
# ===== MENU =====
# 1 - Criar nova forma
# 2 - Calcular áreas
# 3 - Exibir áreas
# 4 - Sair
# Escolha uma opção: 1
#
# 1 - Círculo
# 2 - Retângulo
# 3 - Triângulo
# Escolha o tipo de forma: 2
# Digite a base: 5
# Digite a altura: 10
# Retângulo criado com sucesso!
#
# ===== MENU =====
# 1 - Criar nova forma
# 2 - Calcular áreas
# 3 - Exibir áreas
# 4 - Sair
# Escolha uma opção: 2
# Área do retângulo calculada com sucesso
#
# ===== MENU =====
# 1 - Criar nova forma
# 2 - Calcular áreas
# 3 - Exibir áreas
# 4 - Sair
# Escolha uma opção: 3
# Área: 50.0
#
# ===== MENU =====
# 1 - Criar nova forma
# 2 - Calcular áreas
# 3 - Exibir áreas
# 4 - Sair
